# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewC00273575/Data-Science/blob/master/LinearRegressionTesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
# Out:
# <ipython-input-27-bd8470f34271>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
data = pd.read_csv('/data.csv')
x = data['x']
y = data['y']
plt.scatter(x, y)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Scatter Plot of Data from CSV')
plt.show()

# %%
model = LinearRegression(fit_intercept=True)
x = np.array(x)
y = np.array(y)
model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 30, 100)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit);

# %% [markdown]
# added
# x = np.array(x)
# y = np.array(y)
#
# to fix-> ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %%
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     0.8732394366197181
# Model intercept: 3.0704225352112697
